# %% [markdown]
# # Topic analysis
# I'll read in the whole content data and conduct a topic analysis based on the code made by Luca Nannini.

# %%
import gensim
from gensim import corpora, models, similarities
import pyLDAvis.gensim
from string import digits
import nltk
from nltk.corpus import stopwords
import pandas as pd

from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# %%
## Read in text data, only take the content column and do cleaning on it
## maybe dont do lemmatization?
with open("C:/Users/maris/Documents/Aarhus University/NLP/NLP exam/txt_fb_data.txt", "r", encoding = "utf-8") as myfile:
    orig_text=myfile.read()

#print(orig_text)
#print(len(list(orig_text.Content)))
# Take only the content and split the words
o_content = orig_text.split()

print(o_content[3:10])
print("-----------------------")
#print(o_interviews[3])
#print(type(o_interviews))

#Just the nouns
with open("C:/Users/maris/Documents/Aarhus University/NLP/NLP exam/estnltk/tutorials/nlp_pipeline/all_nouns.txt", "r") as myfile:
    orig_text=myfile.read()

#print(orig_text)
#print(len(list(orig_text.Content)))
# Take only the content and split the words
o_content = orig_text.split()

print(o_content[3:10])
print("-----------------------")
# Out:
# ['Sina?', '🎉', 'Meil', 'on', 'ideaalne', 'idee', 'uusaastalubaduseks']
# -----------------------
# ['liit', 'taimetoit', 'väljakutse', 'jaanuar', 'registreerimine', 'minut', 'kiri']
# -----------------------

# %%
# Make it into a list of words, lowercase them
twtok_text = [
     [word for word in document.lower().split()]
      for document in o_content
 ]
twtok_text[3:10]

# Remove NaN's from the interviews
#o_inter = [x for x in o_interviews if str(x) != 'nan']

#twtok_inter = [
#     [word for word in document.split()]
#      for document in o_inter
#]
#twtok_inter[3]
# Out:
# [['liit'],
#  ['taimetoit'],
#  ['väljakutse'],
#  ['jaanuar'],
#  ['registreerimine'],
#  ['minut'],
#  ['kiri']]

# %%
## For texts:
dictionary = corpora.Dictionary(twtok_text)
print(dictionary)
corpus = [dictionary.doc2bow(text) for text in twtok_text]
# Out:
# Dictionary(729 unique tokens: ['aasta', 'idee', 'uusaastalubadus', 'liit', 'taimetoit']...)

# %%
## For textx:
total_topics = 5
lda = models.LdaModel(corpus, id2word=dictionary, num_topics=total_topics)
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy

# %%
pyLDAvis.enable_notebook()
panel = pyLDAvis.gensim.prepare(lda, corpus, dictionary, mds='TSNE')
panel
# Out:
# WARNING:root:sklearn not present, switch to PCoA
# C:\Users\maris\Anaconda3\envs\est_nlp\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4      0.211898  0.026032       1        1  21.811264
# 2     -0.050008 -0.236090       2        1  20.265085
# 0     -0.147949  0.142806       3        1  19.884188
# 3     -0.123155  0.015232       4        1  19.060402
# 1      0.109213  0.052021       5        1  18.979067, topic_info=    Category        Freq            Term       Total  loglift  logprob
# 22   Default  146.000000            loom  146.000000  30.0000  30.0000
# ...
